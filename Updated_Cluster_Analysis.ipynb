# %% [markdown]
# <a href="https://colab.research.google.com/github/Data-Science-Project-Lifecycle/DSPL_AFTER_FEEDBACK/blob/main/Updated_Cluster_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train=pd.read_csv('train_cleaned.csv')
train
# Out:
#         outlet_city  luxury_sales  fresh_sales  dry_sales  cluster_category
# 0                11       1209.60       756.00    5292.00                 4
# 1                13       1590.12      1060.08    6007.12                 1
# 2                19       2288.88      1481.04    9155.52                 4
# 3                19       2274.94      1739.66    9099.76                 4
# 4                11       2345.49      2069.55    9243.99                 4
# ...             ...           ...          ...        ...               ...
# 774050            4       3893.40      3893.40    3448.44                 3
# 774051           10       6095.86      5557.99    6275.15                 3
# 774052            1       5121.42      4820.16    4669.53                 3
# 774053            9       6311.76      6311.76    5940.48                 3
# 774054           14       5833.50      6027.95    6611.30                 3
#
# [774055 rows x 5 columns]

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='cluster_category', y='fresh_sales', data=train)
plt.title('Distribution of Fresh Sales by Customer Segment')
plt.xlabel('Cluster Category')
plt.ylabel('Fresh Sales')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='cluster_category', y='luxury_sales', data=train)
plt.title('Distribution of luxury Sales by Customer Segment')
plt.xlabel('Cluster Category')
plt.ylabel('luxury Sales')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='cluster_category', y='dry_sales', data=train)
plt.title('Distribution of Dry Sales by Customer Segment')
plt.xlabel('Cluster Category')
plt.ylabel('Dry Sales')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
df_melted = train.melt(id_vars='cluster_category', value_vars=['luxury_sales', 'fresh_sales', 'dry_sales'], var_name='sales_type', value_name='sales_amount')

# Create the grouped boxplot
plt.figure(figsize=(12, 8))
sns.barplot(x='cluster_category', y='sales_amount', hue='sales_type', data=df_melted)

plt.title('Distribution of Sales by Cluster and Product Type')
plt.xlabel('Cluster Category')
plt.ylabel('Sales Amount')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Sales Type')
plt.tight_layout()
plt.show()
